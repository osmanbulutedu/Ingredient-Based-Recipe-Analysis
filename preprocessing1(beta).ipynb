# %% [markdown]
# ### data preprocessing are needed
# ##### all values are in str format. They needed to be converted either int or float format for further steps
# ##### different csv are needed to be merged and NaN values needed to be deleted in a reasonable way

# %%
import pandas as pd
import numpy as np
from nltk.stem import PorterStemmer
from initial_functions import *

# %%
ing=pd.read_csv("/Users/osman/Desktop/Master Project/data/1/ingUnitQuant.csv")
nut=pd.read_csv("/Users/osman/Desktop/Master Project/data/1/nutrient.csv")
serv=pd.read_csv("/Users/osman/Desktop/Master Project/data/1/servings.csv")

# %%
ing[ing['ingredientUnit']=="package"]
# Out:
#                                              recipe  ingredientName  \
# 40      dads-beef-and-chive-dip                      beef
# 41      dads-beef-and-chive-dip                      Cheddar cheese
# 47      palak-paneer-indian-spinach-and-paneer       spinach
# 112     cajun-prime-rib-roast                        mushroom
# 141     ground-turkey-tacos                          taco shells
# ...                     ...                                  ...
# 683553  chicken-breasts-lombardy                     mushroom
# 683618  greek-cucumber-bean-salad                    feta cheese
# 683645  buffalo-chicken-baked-ziti                   cream cheese
# 683650  green-chile-enchiladas-with-leftover-turkey  cheese
# 683652  green-chile-enchiladas-with-leftover-turkey  Cheddar cheese
#
#        ingredientQuantity ingredientUnit
# 40      1                  package
# 41      1                  package
# 47      1                  package
# 112     1                  package
# 141     1                  package
# ...    ..                      ...
# 683553  1                  package
# 683618  1                  package
# 683645  1                  package
# 683650  1                  package
# 683652  1                  package
#
# [16236 rows x 4 columns]

# %%
nut
# Out:
#                                                  recipe  calories  \
# 0      peanut-butter-tandy-bars                          230.0
# 1      the-best-oatmeal-cookies                          172.8
# 2      peach-cobbler-ii                                  672.4
# 3      pie-crust-v                                       210.4
# 4      palak-paneer-indian-spinach-and-paneer            315.1
# ...                                       ...              ...
# 71057  fruity-non-dairy-oatmeal-smoothie                NaN
# 71058  spinach-and-artichoke-dip-stuffed-crescent-rolls  177.3
# 71059  aloo-paratha                                     NaN
# 71060  home-fried-breakfast-potatoes                     342.4
# 71061  fasolada-greek-navy-bean-soup                    NaN
#
#        cholesterol  carbohydrates  protein    fat  saturatedFat  fiber  \
# 0      31.8         32.7           5.8      9.5    3.2           1.6
# 1      29.1         24.8           2.4      7.6    3.6           1.1
# 2      18.5         112.7          4.7      24.0   8.5           1.0
# 3      39.2         22.6           2.9      12.1   7.4           0.6
# 4      17.0         16.3           19.9     20.7   4.5           5.5
# ...     ...          ...            ...      ...   ...           ...
# 71057 NaN           53.3           6.1      3.9    0.4           8.0
# 71058  12.5         14.6           3.8      11.3   3.8           0.5
# 71059 NaN           93.0           16.3     5.1    0.8           14.8
# 71060  13.2         42.8           9.6      15.6   3.1           4.7
# 71061 NaN           69.7           23.0     136.1  19.0          25.6
#
#        sodium  sugar  \
# 0      130.3   22.9
# 1      179.3   14.1
# 2      376.2   88.2
# 3      86.7    4.8
# 4      586.3   3.5
# ...      ...   ...
# 71057  83.6    21.3
# 71058  388.9   2.7
# 71059  14.2    2.0
# 71060  875.0   2.7
# 71061  425.5   11.9
#
#                                                                              category
# 0      http://purl.org/recipekg/categories/desserts/cookies/bar-cookies/
# 1      http://purl.org/recipekg/categories/desserts/cookies/spice-cookies/
# 2      http://purl.org/recipekg/categories/desserts/fruit-desserts/peach-desserts/
# 3      http://purl.org/recipekg/categories/desserts/pies/pie-crusts/pastry-crusts/
# 4      http://purl.org/recipekg/categories/trusted-brands-recipes-and-tips/
# ...                                                                     ...
# 71057  http://purl.org/recipekg/categories/drinks/smoothies/
# 71058  http://purl.org/recipekg/categories/bread/quick-bread/
# 71059  http://purl.org/recipekg/categories/bread/quick-bread/
# 71060  http://purl.org/recipekg/categories/breakfast-and-brunch/potatoes/
# 71061  http://purl.org/recipekg/categories/soups-stews-and-chili/soup/beans-and-peas/
#
# [71062 rows x 11 columns]

# %%
serv
# Out:
#        Unnamed: 0  \
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4
# ...   ..
# 77532  77532
# 77533  77533
# 77534  77534
# 77535  77535
# 77536  77536
#
#                                                                                                      URL  \
# 0      https://www.allrecipes.com/recipe/10336/molasses-cookies-i/
# 1      https://www.allrecipes.com/recipe/220584/fried-irish-cabbage-with-bacon/
# 2      https://www.allrecipes.com/recipe/261330/dairy-nut-and-gluten-free-green-bean-casserole/
# 3      https://www.allrecipes.com/recipe/178366/steamed-blue-crabs/
# 4      https://www.allrecipes.com/recipe/20939/lightning-gravy/
# ...                                                         ...
# 77532  https://www.allrecipes.com/recipe/284064/inside-out-air-fried-eggplant-parm/
# 77533  https://www.allrecipes.com/recipe/245871/falafel-burgers/
# 77534  https://www.allrecipes.com/recipe/246694/haemoolpa-jun-pan-fried-seafood-and-green-onion-pancake/
# 77535  https://www.allrecipes.com/recipe/258148/jacques-fresh-corn-fritters/
# 77536  https://www.allrecipes.com/recipe/15017/cheese-crispies/
#
#       Servings                                                   recipe
# 0      60       molasses-cookies-i
# 1      6        fried-irish-cabbage-with-bacon
# 2      10       dairy-nut-and-gluten-free-green-bean-casserole
# 3      6        steamed-blue-crabs
# 4      16       lightning-gravy
# ...    ..                   ...
# 77532  2        inside-out-air-fried-eggplant-parm
# 77533  4        falafel-burgers
# 77534  4        haemoolpa-jun-pan-fried-seafood-and-green-onion-pancake
# 77535  6        jacques-fresh-corn-fritters
# 77536  20       cheese-crispies
#
# [77537 rows x 4 columns]

# %%
#truncate the recipes that dont have a serving information
#and convert them to float
#only 3 recipes are truncated

serv=serv[serv["Servings"]!="url error"]
#converting the serving information to int from string
serv['Servings'] = pd.to_numeric(serv['Servings'], errors='coerce').fillna(0).astype(int)
serv=serv[serv["Servings"]!=0].reset_index(drop=True)
serv=serv.drop(serv.columns[0], axis=1)
# Out:
# <ipython-input-707-17d6178844dd>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   serv['Servings'] = pd.to_numeric(serv['Servings'], errors='coerce').fillna(0).astype(int)

# %%
#adding servings information to the ingredient table
ing1=ing.merge(serv, on='recipe', how='inner')
#convert everthing lower case
ing1['ingredientName'] = ing1['ingredientName'].str.lower()
ing1['ingredientUnit'] = ing1['ingredientUnit'].str.lower()

# %%
#delete units' recipes that are used less than 50 times
ing1=trun(ing1, "URL", "ingredientUnit",50)

# %% [markdown]
# ### eger stemmer uygulamak istersen
# ##### now the stemmer will be applied and unique ingredients woill be decreased 6271 to 5927.
# stemmer = PorterStemmer()
#
# ##### define a lambda function to apply the stemmer to each element in the column
# stem_function = lambda x: stemmer.stem(x)
#
# ##### apply the lambda function to the 'Ingredients' column using the apply() method
# ing1['Stemmed'] = ing1['ingredientName'].apply(stem_function)
# ing1['Stemmed'].nunique()

# %%
##### iki ayri yol var. biri sadece 100 un altindaki ingredintleri silmek.ing2 bu
#### digeri 100 un altinda olan ingredient lara sahip recipe leri silmek. ing3 bu
### ayrica 3un altinda ingredient i olanlari siliyorum. yalniz bunu ing2 icin sonra ing3 icin once yapmaliyiz.

# %%
#delete the rows(ingredients) that have NaN values in unit and quantity at the same time

ing1=ing1[~(ing1.ingredientQuantity.isnull() & ing1.ingredientUnit.isnull())].reset_index(drop=True)

# %%
#adding "piece" as a unit if the unit is still NaN
#because almost all of them meant to be "piece" i.e 1 potato, 1 onion etc.
ing1.ingredientUnit.fillna("piece", inplace=True)

# %%
#deleting recipes that have NaN values in quantity is necessary. Especially for salt. We need to know amount of salt.
#because we will use the quantity information to calculate the nutrient values.And salt and others are important.
#deleting only those rows would have been wrong.Bcs it cahanges the recipe.
#but deleting only rows can be tried as well before ml part.
#so in this step we are losing aroung 4k recipes

print(ing1[ing1.ingredientQuantity.isnull()].URL.nunique())
delrec=ing1[ing1.ingredientQuantity.isnull()].URL.unique() #recipes that have NaN values in quantity
ing1=ing1[~ing1.URL.isin(delrec)].reset_index(drop=True) #deleting those recipes
# Out:
# 4159

# %%
#delete the ingredients which are used less then 100 in our dataset
#this one only truncates ingredients, NOT the whole recipes!

ing2=ing1[ing1['ingredientName'].map(ing1['ingredientName'].value_counts()) > 100].reset_index(drop=True)
#recipes that have less than 3 ingredients will be truncated. about 1k recipes
ing2=ing2[~(ing2['recipe'].map(ing2['recipe'].value_counts()) < 3)].reset_index(drop=True)

# %%
#recipes that have less than 3 ingredients will be truncated. about 1k recipes
#we loose 1254 recipes here
print(ing1[(ing1['recipe'].map(ing1['recipe'].value_counts()) < 3)].URL.nunique())
ing1=ing1[~(ing1['recipe'].map(ing1['recipe'].value_counts()) < 3)].reset_index(drop=True)
# Out:
# 1254

# %%
#delete the recipes that have ingredients which are used less then 100 in our dataset
#this one truncates the whole recipes, NOT the ingredients!
#we had 5877 unique igredients before this step. 
#5424 of themwill be truncated after this step. This will cause loosing 30542 recipes (from 70k to 40k) 
# these are dramatic numbers, needed to be considered again and this step might be passed before ml steps for a try.


ing3=trun(ing1, "URL", "ingredientName",100)
ing3.URL.nunique()
# Out:
# 40089

# %%
#converting the str values of quantities to float by using an external function

ing3['ingredientQuantity'] = ing3['ingredientQuantity'].apply(convert_to_float)

#10 recipes that still have NaN values in quantity will be truncated
print(ing3[ing3.ingredientQuantity.isnull()].URL.nunique())
delrec=ing3[ing3.ingredientQuantity.isnull()].URL.unique() #recipes that have NaN values in quantity
ing3=ing3[~ing3.URL.isin(delrec)].reset_index(drop=True) #deleting those recipes
# Out:
# 10

# %%
# first part of the preprocessing is done.
#there is no missing values in the dataset now.
#unit normalization might be done before ml part in the next step.
print("recipe number:",ing3.URL.nunique(),"\n",
      "unique ingredient number:",ing3.ingredientName.nunique(),"\n",
      "unique unit number:",ing3.ingredientUnit.nunique())
# Out:
# recipe number: 40079
#  unique ingredient number: 453
#  unique unit number: 31

# %%
#save to csv

ing3.to_csv("/Users/osman/Desktop/Master Project/data/2/recipe40k.csv", index=False)

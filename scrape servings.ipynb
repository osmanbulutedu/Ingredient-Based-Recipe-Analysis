# %% [markdown]
# ### this is the way scrapping servings per recipe from allrecipes.com

# %%
import pandas as pd
from initial_functions import *

# %%
#scraping the urls from the json files
myfiles = ['/Users/osman/Desktop/Master Project/data/RecipeKG/RecipeKG-main/Data/Json-Data/recipes1/',
            '/Users/osman/Desktop/Master Project/data/RecipeKG/RecipeKG-main/Data/Json-Data/recipes2/',
            '/Users/osman/Desktop/Master Project/data/RecipeKG/RecipeKG-main/Data/Json-Data/recipes3/',
            '/Users/osman/Desktop/Master Project/data/RecipeKG/RecipeKG-main/Data/Json-Data/recipes4/',
            '/Users/osman/Desktop/Master Project/data/RecipeKG/RecipeKG-main/Data/Json-Data/recipes5/',
            '/Users/osman/Desktop/Master Project/data/RecipeKG/RecipeKG-main/Data/Json-Data/recipes6/',
            '/Users/osman/Desktop/Master Project/data/RecipeKG/RecipeKG-main/Data/Json-Data/recipes7/',
            '/Users/osman/Desktop/Master Project/data/RecipeKG/RecipeKG-main/Data/Json-Data/recipes8/']

urls=scrap_url(myfiles)

# %%
urls
# Out:
# ['https://www.allrecipes.com/recipe/10336/molasses-cookies-i/',
#  'https://www.allrecipes.com/recipe/220584/fried-irish-cabbage-with-bacon/',
#  'https://www.allrecipes.com/recipe/261330/dairy-nut-and-gluten-free-green-bean-casserole/',
#  'https://www.allrecipes.com/recipe/178366/steamed-blue-crabs/',
#  'https://www.allrecipes.com/recipe/20939/lightning-gravy/',
#  'https://www.allrecipes.com/recipe/213665/smokin-jack-bbq-sauce/',
#  'https://www.allrecipes.com/recipe/143424/mensaf-jordanian-lamb-stew/',
#  'https://www.allrecipes.com/recipe/232827/bacon-and-eggs-potato-salad/',
#  'https://www.allrecipes.com/recipe/221143/the-ultimate-margarita/',
#  'https://www.allrecipes.com/recipe/12058/pasta-with-sweet-peas/',
#  'https://www.allrecipes.com/recipe/8999/vals-hungarian-jewish-chopped-liver/',
#  'https://www.allrecipes.com/recipe/232358/homemade-mint-chocolate-chip-ice-cream/',
#  'https://www.allrecipes.com/recipe/281881/pasta-with-roasted-cauliflower-and-parmesan/',
# ...

# %%
#scraping the servings amount of recipes from the urls of allrecipes.com
servings=serve_amount(urls)

# %%
servings["recipe"]=servings["URL"].str.rsplit('/',2).str[-2]
servings
# Out:
#                                                                                                      URL  \
# 0                                            https://www.allrecipes.com/recipe/10336/molasses-cookies-i/
# 1                               https://www.allrecipes.com/recipe/220584/fried-irish-cabbage-with-bacon/
# 2               https://www.allrecipes.com/recipe/261330/dairy-nut-and-gluten-free-green-bean-casserole/
# 3                                           https://www.allrecipes.com/recipe/178366/steamed-blue-crabs/
# 4                                               https://www.allrecipes.com/recipe/20939/lightning-gravy/
# ...                                                                                                  ...
# 77532                       https://www.allrecipes.com/recipe/284064/inside-out-air-fried-eggplant-parm/
# 77533                                          https://www.allrecipes.com/recipe/245871/falafel-burgers/
# ...

# %%
#export to csv
servings.to_csv("/Users/osman/Desktop/Master Project/data/1/servings.csv")
